# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime

#this is a python magic function to automatically show matplotlib plots
# %matplotlib inline

# %%
june = pd.read_pickle('../data/june.pkl')
june_trips = pd.read_csv('../data/june_trip.csv')

# %%
july = pd.read_pickle('../data/july.pkl')
july_trips = pd.read_csv('../data/july_trip.csv')

# %%
may = pd.read_pickle('../data/may.pkl')
may_trips = pd.read_csv('../data/may_trip.csv')

# %%
may_trips.head(20)
# Out:
#                   pubTimeStamp companyName tripRecordNum         sumdID  \
# 0   2019-05-01 00:00:55.423000        Bird       BRD2134   Powered9EAJL
# 1   2019-05-01 00:03:33.147000        Lyft          LFT5  Powered296631
# 2   2019-05-01 00:05:55.570000        Bird       BRD2168   Powered7S2UU
# 3   2019-05-01 00:05:55.570000        Bird       BRD2166   PoweredZIIVX
# 4   2019-05-01 00:05:55.570000        Bird       BRD2165   PoweredJ7MB3
# 5   2019-05-01 00:05:55.570000        Bird       BRD2167   PoweredEJF1K
# 6   2019-05-01 00:07:55.880000        Lyft         LFT10  Powered329418
# 7   2019-05-01 00:10:50.240000        Lyft         LFT13  Powered438572
# 8   2019-05-01 00:10:56.013000        Bird       BRD2193   PoweredSX2AW
# 9   2019-05-01 00:10:56.013000        Bird       BRD2194   PoweredL968V
# 10  2019-05-01 00:10:56.013000        Bird       BRD2191   PoweredVS299
# 11  2019-05-01 00:10:56.013000        Bird       BRD2192   Powered9DC3R
# ...

# %%
may_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224969 entries, 0 to 224968
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pubTimeStamp    224969 non-null  object
#  1   companyName     224969 non-null  object
#  2   tripRecordNum   224969 non-null  object
#  3   sumdID          224969 non-null  object
#  4   tripDuration    224969 non-null  float64
#  5   tripDistance    224969 non-null  float64
#  6   startDate       224969 non-null  object
#  7   startTime       224969 non-null  object
#  8   endDate         224969 non-null  object
#  9   endTime         224969 non-null  object
#  10  startLatitude   224969 non-null  float64
#  11  startLongitude  224969 non-null  float64
#  12  endLatitude     224969 non-null  float64
#  13  endLongitude    224969 non-null  float64
#  14  tripRoute       224969 non-null  object
#  15  create_dt       224969 non-null  object
# dtypes: float64(6), object(10)
# ...

# %%
july_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134926 entries, 0 to 134925
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pubTimeStamp    134926 non-null  object
#  1   companyName     134926 non-null  object
#  2   tripRecordNum   134926 non-null  object
#  3   sumdID          134926 non-null  object
#  4   tripDuration    134926 non-null  float64
#  5   tripDistance    134926 non-null  float64
#  6   startDate       134926 non-null  object
#  7   startTime       134926 non-null  object
#  8   endDate         134926 non-null  object
#  9   endTime         134926 non-null  object
#  10  startLatitude   134926 non-null  float64
#  11  startLongitude  134926 non-null  float64
#  12  endLatitude     134926 non-null  float64
#  13  endLongitude    134926 non-null  float64
#  14  tripRoute       134926 non-null  object
#  15  create_dt       134926 non-null  object
# dtypes: float64(6), object(10)
# ...

# %%
june_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205627 entries, 0 to 205626
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pubTimeStamp    205627 non-null  object
#  1   companyName     205627 non-null  object
#  2   tripRecordNum   205627 non-null  object
#  3   sumdID          205627 non-null  object
#  4   tripDuration    205627 non-null  float64
#  5   tripDistance    205627 non-null  float64
#  6   startDate       205627 non-null  object
#  7   startTime       205627 non-null  object
#  8   endDate         205627 non-null  object
#  9   endTime         205627 non-null  object
#  10  startLatitude   205627 non-null  float64
#  11  startLongitude  205627 non-null  float64
#  12  endLatitude     205627 non-null  float64
#  13  endLongitude    205627 non-null  float64
#  14  tripRoute       205627 non-null  object
#  15  create_dt       205627 non-null  object
# dtypes: float64(6), object(10)
# ...

# %%
may.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20283582 entries, 0 to 20283581
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pubdatetime  datetime64[ns]
#  1   latitude     float64
#  2   longitude    float64
#  3   sumdid       object
#  4   chargelevel  float64
#  5   companyname  int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 928.5+ MB

# %%
june.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28037408 entries, 0 to 28037407
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pubdatetime  datetime64[ns]
#  1   latitude     float64
#  2   longitude    float64
#  3   sumdid       object
#  4   chargelevel  float64
#  5   companyname  int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 1.3+ GB

# %%
july.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25066524 entries, 0 to 25075444
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pubdatetime  datetime64[ns]
#  1   latitude     float64
#  2   longitude    float64
#  3   sumdid       object
#  4   chargelevel  float64
#  5   companyname  int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 1.3+ GB

# %%
may.isnull().sum()
# Out:
# pubdatetime      0
# latitude         0
# longitude        0
# sumdid           0
# chargelevel    283
# companyname      0
# dtype: int64

# %%
june.isnull().sum()
# Out:
# pubdatetime      0
# latitude         0
# longitude        0
# sumdid           0
# chargelevel    285
# companyname      0
# dtype: int64

# %%
july.isnull().sum()
# Out:
# pubdatetime      0
# latitude         0
# longitude        0
# sumdid           0
# chargelevel    202
# companyname      0
# dtype: int64

# %%
may_trips.isnull().sum()
# Out:
# pubTimeStamp      0
# companyName       0
# tripRecordNum     0
# sumdID            0
# tripDuration      0
# tripDistance      0
# startDate         0
# startTime         0
# endDate           0
# endTime           0
# startLatitude     0
# startLongitude    0
# endLatitude       0
# endLongitude      0
# tripRoute         0
# create_dt         0
# dtype: int64

# %%
june_trips.isnull().sum()
# Out:
# pubTimeStamp      0
# companyName       0
# tripRecordNum     0
# sumdID            0
# tripDuration      0
# tripDistance      0
# startDate         0
# startTime         0
# endDate           0
# endTime           0
# startLatitude     0
# startLongitude    0
# endLatitude       0
# endLongitude      0
# tripRoute         0
# create_dt         0
# dtype: int64

# %%
july_trips.isnull().sum()
# Out:
# pubTimeStamp      0
# companyName       0
# tripRecordNum     0
# sumdID            0
# tripDuration      0
# tripDistance      0
# startDate         0
# startTime         0
# endDate           0
# endTime           0
# startLatitude     0
# startLongitude    0
# endLatitude       0
# endLongitude      0
# tripRoute         0
# create_dt         0
# dtype: int64

# %%
column_names = ['pubdatetime', 'sumdid']
maydup = may.duplicated(subset = column_names, keep = False).sum()
maydup
# Out:
# 0

# %%
column_names = ['pubdatetime', 'sumdid']
junedup = june.duplicated(subset = column_names, keep = False).sum()
junedup
# Out:
# 0

# %%
column_names = ['pubdatetime', 'sumdid']
julydup = july.duplicated(subset = column_names, keep = False).sum()
julydup
# Out:
# 0

# %%
tripcolnames = ['startDate', 'tripRoute', 'startTime', 'endDate', 'endTime', 'sumdID', 'startLatitude', 'startLongitude', 'endLatitude', 'endLongitude']
may_tripsdup = may_trips.duplicated(subset = tripcolnames, keep = False).sum()
may_tripsdup
# Out:
# 31376

# %%
tripcolnames = ['startDate', 'tripRoute', 'startTime', 'endDate', 'endTime', 'sumdID', 'startLatitude', 'startLongitude', 'endLatitude', 'endLongitude']
june_tripsdup = june_trips.duplicated(subset = tripcolnames, keep = False).sum()
june_tripsdup
# Out:
# 13820

# %%
tripcolnames = ['startDate', 'tripRoute', 'startTime', 'endDate', 'endTime', 'sumdID', 'startLatitude', 'startLongitude', 'endLatitude', 'endLongitude']
july_tripsdup = july_trips.duplicated(subset = tripcolnames, keep = False).sum()
july_tripsdup
# Out:
# 477

# %%
tripcolnames = ['startDate', 'tripRoute', 'startTime', 'endDate', 'endTime', 'sumdID', 'startLatitude', 'startLongitude', 'endLatitude', 'endLongitude']
may_tripsdup = may_trips.duplicated(subset = tripcolnames, keep = False).sum()

# %%
may_trips_dedup = may_trips.drop_duplicates(subset = ['startDate', 'tripRoute', 'startTime', 'endDate', 'endTime', 'sumdID', 'startLatitude', 'startLongitude', 'endLatitude', 'endLongitude'], keep = 'first')
may_trips_dedup.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum         sumdID  \
# 0  2019-05-01 00:00:55.423000        Bird       BRD2134   Powered9EAJL
# 1  2019-05-01 00:03:33.147000        Lyft          LFT5  Powered296631
# 2  2019-05-01 00:05:55.570000        Bird       BRD2168   Powered7S2UU
# 3  2019-05-01 00:05:55.570000        Bird       BRD2166   PoweredZIIVX
# 4  2019-05-01 00:05:55.570000        Bird       BRD2165   PoweredJ7MB3
#
#    tripDuration  tripDistance            startDate        startTime  \
# 0        3.0000     958.00528  2019-05-01 00:00:00  00:00:20.460000
# 1        1.7156    1371.39112  2019-05-01 00:00:00  00:01:50.090000
# 2        3.0000    2296.58800  2019-05-01 00:00:00  00:03:47.363333
# 3        3.0000    1200.78744  2019-05-01 00:00:00  00:04:21.386666
# 4        2.0000     351.04988  2019-05-01 00:00:00  00:04:27.796666
#
#                endDate          endTime  startLatitude  startLongitude  \
# ...

# %%
tripcolnames = ['startDate', 'tripRoute', 'startTime', 'endDate', 'endTime', 'sumdID', 'startLatitude', 'startLongitude', 'endLatitude', 'endLongitude']
may_tripsdup = may_trips_dedup.duplicated(subset = tripcolnames, keep = False).sum()
may_tripsdup
# Out:
# 0

# %%
may_trips_dedup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199984 entries, 0 to 224968
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pubTimeStamp    199984 non-null  object
#  1   companyName     199984 non-null  object
#  2   tripRecordNum   199984 non-null  object
#  3   sumdID          199984 non-null  object
#  4   tripDuration    199984 non-null  float64
#  5   tripDistance    199984 non-null  float64
#  6   startDate       199984 non-null  object
#  7   startTime       199984 non-null  object
#  8   endDate         199984 non-null  object
#  9   endTime         199984 non-null  object
#  10  startLatitude   199984 non-null  float64
#  11  startLongitude  199984 non-null  float64
#  12  endLatitude     199984 non-null  float64
#  13  endLongitude    199984 non-null  float64
#  14  tripRoute       199984 non-null  object
#  15  create_dt       199984 non-null  object
# dtypes: float64(6), object(10)
# ...

# %%
#converting date/times to date/times
june_trips.startTime = pd.DatetimeIndex(june_trips['startTime']).time
june_trips.startDate = pd.to_datetime(june_trips.startDate)
june_trips.endTime = pd.DatetimeIndex(june_trips['endTime']).time
june_trips.endDate = pd.to_datetime(june_trips.endDate)
june_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205627 entries, 0 to 205626
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   pubTimeStamp    205627 non-null  object
#  1   companyName     205627 non-null  object
#  2   tripRecordNum   205627 non-null  object
#  3   sumdID          205627 non-null  object
#  4   tripDuration    205627 non-null  float64
#  5   tripDistance    205627 non-null  float64
#  6   startDate       205627 non-null  datetime64[ns]
#  7   startTime       205627 non-null  object
#  8   endDate         205627 non-null  datetime64[ns]
#  9   endTime         205627 non-null  object
#  10  startLatitude   205627 non-null  float64
#  11  startLongitude  205627 non-null  float64
#  12  endLatitude     205627 non-null  float64
#  13  endLongitude    205627 non-null  float64
#  14  tripRoute       205627 non-null  object
#  15  create_dt       205627 non-null  object
# ...

# %%
fig = plt.scatter("tripDuration", "tripDistance", data = june_trips, color = '#1F375D', s = .5)
plt.title('Duration v. Distance Before Cleaning')
plt.xlabel('Duration in Hours')
plt.ylabel("Distance in 10's of Millions of Feet")
# Out:
# Text(0, 0.5, "Distance in 10's of Millions of Feet")

# %%
sub = june_trips.loc[june_trips['tripDistance'] < 21120]
#sub = sub.loc[sub['tripDistance'] > 0]
fig = plt.scatter("tripDuration", "tripDistance", data = sub, color = '#1F375D', s = .5)
plt.title('Zoom in: Trips Under 4 Miles')
plt.xlabel('Duration in Hours')
plt.ylabel("Distance in Feet")
# Out:
# Text(0, 0.5, 'Distance in Feet')

# %%
plt.hist(june_trips.tripDuration, color = '#1F375D', bins = 40)
plt.title('Duration Distribution Before Cleaning')
plt.xlabel("Duration in Hours")
plt.ylabel('Count of Trips')
# Out:
# Text(0, 0.5, 'Count of Trips')

# %%
dursub = june_trips.loc[june_trips['tripDuration'] < 100]
plt.hist(dursub.tripDuration, bins = 40, color = '#1F375D')
plt.title('Zoom in: Trips Under 100 Hours')
plt.xlabel("Duration in Hours")
plt.ylabel('Count of Trips')
# Out:
# Text(0, 0.5, 'Count of Trips')

# %%
subdist = june_trips.loc[june_trips['tripDistance'] < 52800]
subdist = subdist.loc[subdist['tripDistance'] > 0]
plt.hist(june_trips.tripDistance, color = '#1F375D', bins = 40)
plt.title('Trip Distance Distribution Before Cleaning')
plt.xlabel("Distance in 10's of Millions of Feet")
plt.ylabel('Count of Trips')
# Out:
# Text(0, 0.5, 'Count of Trips')

# %%
subdist = june_trips.loc[june_trips['tripDistance'] < 52800]
subdist = subdist.loc[subdist['tripDistance'] > 0]
plt.hist(subdist.tripDistance, color = '#1F375D', bins = 40)
plt.title('Zoom In: Trips Under 10 Miles')
plt.xlabel("Distance in Feet")
plt.ylabel('Count of Trips')
# Out:
# Text(0, 0.5, 'Count of Trips')

# %%
plt.hist(june_trips.tripDistance, color = '#1F375D', bins = 40)
plt.title('Distribution of Trip Distance in June')
plt.xlabel("Distance in 10's of Millions of Feet")
plt.ylabel('Count of Trips')

# %%
plt.hist(june_trips.startDate, bins = 30)
plt.xticks(rotation=50)
plt.title('Date Distribution')
plt.show()

# %%
june.sumdid.nunique()
# Out:
# 7822

# %% [markdown]
# ## We got 7,822 scooters

# %%
#converting to strings to concat into new datetime columns
june_trips['endDate'] = june_trips['endDate'].astype('str')
june_trips['endTime'] = june_trips['endTime'].astype('str')
june_trips['endDateTime_clean'] = june_trips['endDate'] + ' ' + june_trips['endTime']
june_trips['startDate'] = june_trips['startDate'].astype('str')
june_trips['startTime'] = june_trips['startTime'].astype('str')
june_trips['startDateTime_clean'] = june_trips['startDate'] + ' ' + june_trips['startTime']
june_trips.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum        sumdID  \
# 0  2019-06-01 00:05:46.817000        Bird       BRD3572  PoweredSPI1T
# 1  2019-06-01 00:05:46.817000        Bird       BRD3571  Powered2I3MS
# 2         2019-06-01 00:09:54      Gotcha          GOT1    Powered327
# 3  2019-06-01 00:10:46.957000        Bird       BRD3610  Powered8U1A6
# 4  2019-06-01 00:10:46.957000        Bird       BRD3612  PoweredSPI1T
#
#    tripDuration  tripDistance   startDate        startTime     endDate  \
# 0           4.0    328.084000  2019-06-01  00:02:18.203333  2019-06-01
# 1           5.0   4921.260000  2019-06-01  00:02:44.803333  2019-06-01
# 2          12.0     12.426575  2019-06-01         00:09:56  2019-06-01
# 3           2.0      0.000000  2019-06-01  00:10:31.163333  2019-06-01
# 4           5.0    656.168000  2019-06-01  00:07:21.430000  2019-06-01
#
#            endTime  startLatitude  startLongitude  endLatitude  endLongitude  \
# ...

# %%
#converting back to datetimes
june_trips.startTime = pd.DatetimeIndex(june_trips['startTime']).time
june_trips.startDate = pd.to_datetime(june_trips.startDate)
june_trips.endTime = pd.DatetimeIndex(june_trips['endTime']).time
june_trips.endDate = pd.to_datetime(june_trips.endDate)
june_trips.startDateTime_clean = pd.to_datetime(june_trips.startDateTime_clean)
june_trips.endDateTime_clean = pd.to_datetime(june_trips.endDateTime_clean)

june_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205627 entries, 0 to 205626
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   pubTimeStamp         205627 non-null  object
#  1   companyName          205627 non-null  object
#  2   tripRecordNum        205627 non-null  object
#  3   sumdID               205627 non-null  object
#  4   tripDuration         205627 non-null  float64
#  5   tripDistance         205627 non-null  float64
#  6   startDate            205627 non-null  datetime64[ns]
#  7   startTime            205627 non-null  object
#  8   endDate              205627 non-null  datetime64[ns]
#  9   endTime              205627 non-null  object
#  10  startLatitude        205627 non-null  float64
#  11  startLongitude       205627 non-null  float64
#  12  endLatitude          205627 non-null  float64
#  13  endLongitude         205627 non-null  float64
# ...

# %%
june_trips['duration_clean'] = june_trips['endDateTime_clean'] - june_trips['startDateTime_clean']
june_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205627 entries, 0 to 205626
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   pubTimeStamp         205627 non-null  object
#  1   companyName          205627 non-null  object
#  2   tripRecordNum        205627 non-null  object
#  3   sumdID               205627 non-null  object
#  4   tripDuration         205627 non-null  float64
#  5   tripDistance         205627 non-null  float64
#  6   startDate            205627 non-null  datetime64[ns]
#  7   startTime            205627 non-null  object
#  8   endDate              205627 non-null  datetime64[ns]
#  9   endTime              205627 non-null  object
#  10  startLatitude        205627 non-null  float64
#  11  startLongitude       205627 non-null  float64
#  12  endLatitude          205627 non-null  float64
#  13  endLongitude         205627 non-null  float64
# ...

# %%
#converting to a usable type. 
june_trips['duration_sec'] = (june_trips.duration_clean / np.timedelta64(1,'s')).astype(int)
june_trips['duration_min'] = june_trips.duration_sec / 60
june_trips.head()
# Out:
#                  pubTimeStamp companyName tripRecordNum        sumdID  \
# 0  2019-06-01 00:05:46.817000        Bird       BRD3572  PoweredSPI1T
# 1  2019-06-01 00:05:46.817000        Bird       BRD3571  Powered2I3MS
# 2         2019-06-01 00:09:54      Gotcha          GOT1    Powered327
# 3  2019-06-01 00:10:46.957000        Bird       BRD3610  Powered8U1A6
# 4  2019-06-01 00:10:46.957000        Bird       BRD3612  PoweredSPI1T
#
#    tripDuration  tripDistance  startDate        startTime    endDate  \
# 0           4.0    328.084000 2019-06-01  00:02:18.203333 2019-06-01
# 1           5.0   4921.260000 2019-06-01  00:02:44.803333 2019-06-01
# 2          12.0     12.426575 2019-06-01         00:09:56 2019-06-01
# 3           2.0      0.000000 2019-06-01  00:10:31.163333 2019-06-01
# 4           5.0    656.168000 2019-06-01  00:07:21.430000 2019-06-01
#
#            endTime  ...  startLongitude  endLatitude  endLongitude  \
# ...

# %%
#switching trips to our pkl files
june_trips = pd.read_pickle('../data/june_trips.pkl')
july_trips = pd.read_pickle('../data/july_trips.pkl')
may_trips = pd.read_pickle('../data/may_trips.pkl')

# %% [markdown]
# removing outliers

# %%
may_trips.describe()
# Out:
#        tripDistance  startLatitude  startLongitude    endLatitude  \
# count  1.999840e+05  199984.000000   199984.000000  199984.000000
# mean   4.285677e+03      36.157158      -86.783764      36.157368
# std    2.757440e+04       0.011465        0.013865       0.019674
# min   -2.758530e+06      36.037283      -86.918008      32.775953
# 25%    3.499104e+02      36.151328      -86.791090      36.151420
# 50%    1.968504e+03      36.158132      -86.781159      36.158407
# 75%    5.853821e+03      36.163162      -86.776100      36.163200
# max    7.580026e+06      36.293024      -86.600733      39.997793
#
#         endLongitude             duration_clean   duration_min
# count  199984.000000                     199984  199984.000000
# mean      -86.783738  0 days 00:16:01.162363074      16.014916
# std         0.074713  0 days 01:36:58.617118174      96.977005
# min      -117.076117     0 days 00:00:00.873333       0.000000
# ...

# %%
june_trips.describe()
# Out:
#        tripDistance  startLatitude  startLongitude    endLatitude  \
# count  1.961970e+05  196197.000000   196197.000000  196197.000000
# mean   5.212037e+03      36.157057      -86.784456      36.156915
# std    4.472925e+04       0.011293        0.013947       0.173339
# min   -5.157480e+05      36.042892      -86.917893     -36.850405
# 25%    8.825460e+02      36.151260      -86.791957      36.151307
# 50%    3.280840e+03      36.157600      -86.781766      36.157900
# 75%    6.889764e+03      36.163200      -86.776401      36.163215
# max    1.848950e+07      36.300029      -86.602127      47.613101
#
#         endLongitude             duration_clean   duration_min
# count  196197.000000                     196197  196197.000000
# mean      -86.784208  0 days 00:15:57.990102533      15.962576
# std         0.618078  0 days 00:46:19.720056829      46.328800
# min      -122.428964   -1 days +23:51:59.776666      -8.000000
# ...

# %%
july_trips.describe()
# Out:
#        tripDistance  startLatitude  startLongitude    endLatitude  \
# count  1.346690e+05  134669.000000   134669.000000  134669.000000
# mean   5.340580e+03      36.156740      -86.785129      36.156683
# std    1.407391e+05       0.010919        0.013979       0.118574
# min   -2.032480e+07      35.853200      -86.890850       0.000000
# 25%    3.280840e+02      36.150941      -86.793100      36.151024
# 50%    2.956037e+03      36.157200      -86.782100      36.157690
# 75%    6.917801e+03      36.162900      -86.776690      36.162800
# max    3.188448e+07      36.299569      -86.366200      51.045409
#
#         endLongitude             duration_clean   duration_min
# count  134669.000000                     134669  134669.000000
# mean      -86.785502  0 days 00:16:05.190755903      16.082017
# std         0.396876  0 days 00:37:19.064066871      37.317952
# min      -122.673729   -1 days +23:40:38.506667     -19.350000
# ...

# %%
dursub = june_trips.loc[june_trips['duration_min'] < 1000]
dursub = dursub.loc[distsub['tripDistance'] > 0]
plt.hist(dursub.duration_min, bins = 40, color = '#729CAA')
plt.title('Duration Histogram Using Minutes')
plt.xlabel("Duration in Minutes")
plt.ylabel('Count of Trips')
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-177-c650c52c0985> in <module>
#       1 dursub = june_trips.loc[june_trips['duration_min'] < 1000]
# ----> 2 dursub = dursub.loc[distsub['tripDistance'] > 0]
#       3 plt.hist(dursub.duration_min, bins = 40, color = '#729CAA')
#       4 plt.title('Duration Histogram Using Minutes')
#       5 plt.xlabel("Duration in Minutes")
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\envs\geospatial\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...

# %% [markdown]
# may duration cutoff: <br>
# 18.633 - 4.95 = 13.683 * 1.5 = 20.5245<br>
# 18.633 + 20.5245 = 39.1575 (upper range)<br>
# <br>
# june duration cutoff:<br>
# 18.5 - 5 = 13.5 * 1.5 = 20.25<br>
# 18.5 + 20.25 = 38.75 (upper range)<br>
# <br>
# july duration cutoff:<br>
# 19.567 - 5 = 14.567 * 1.5 = 21.851<br>
# 19.567 + 21.851 = 41.4175 (upper range)

# %% [markdown]
# don't understand distance stuff, gonna cut off at 10 miles

# %%
distsub = june_trips.loc[june_trips['tripDistance'] < 52800]
distsub = distsub.loc[distsub['tripDistance'] > 0]
plt.hist(distsub.tripDistance, bins = 40, color = '#729CAA')
plt.title('trips under 10 miles')
plt.xlabel("Distance in Feet")
plt.ylabel('Count of Trips')
# Out:
# Text(0, 0.5, 'Count of Trips')

# %%
may_trips = may_trips.loc[may_trips['duration_min'] < 39.16]
may_trips = may_trips.loc[may_trips['duration_min'] > 0]
may_trips = may_trips.loc[may_trips['tripDistance'] < 52800]
may_trips = may_trips.loc[may_trips['tripDistance'] > 0]
may_trips.describe()
# Out:
#         tripDistance  startLatitude  startLongitude    endLatitude  \
# count  166645.000000  166645.000000   166645.000000  166645.000000
# mean     3817.047020      36.157097      -86.783733      36.157289
# std      4311.945364       0.011572        0.013782       0.018295
# min         0.083756      36.037283      -86.918008      32.775953
# 25%       542.239200      36.151300      -86.791059      36.151400
# 50%      2296.588000      36.158000      -86.781206      36.158300
# 75%      5636.414400      36.163116      -86.776120      36.163123
# max     43333.334720      36.293024      -86.608901      39.768425
#
#         endLongitude             duration_clean   duration_min
# count  166645.000000                     166645  166645.000000
# mean      -86.783766  0 days 00:12:10.934653747      12.177987
# std         0.079277  0 days 00:08:40.272211743       8.671139
# min      -117.076117     0 days 00:00:05.450000       0.083333
# ...

# %%
june_trips = june_trips.loc[june_trips['duration_min'] < 38.75]
june_trips = june_trips.loc[june_trips['duration_min'] > 0]
june_trips = june_trips.loc[june_trips['tripDistance'] < 52800]
june_trips = june_trips.loc[june_trips['tripDistance'] > 0]
june_trips.describe()
# Out:
#         tripDistance  startLatitude  startLongitude    endLatitude  \
# count  151577.000000  151577.000000   151577.000000  151577.000000
# mean     4971.000252      36.156997      -86.784370      36.156728
# std      4221.171577       0.011456        0.013823       0.192840
# min         0.076653      36.042892      -86.917893     -36.850405
# 25%      1919.291400      36.151233      -86.791800      36.151339
# 50%      3900.871200      36.157560      -86.781870      36.157872
# 75%      6889.764000      36.163200      -86.776450      36.163200
# max     51931.783200      36.300029      -86.602127      47.237628
#
#         endLongitude             duration_clean   duration_min
# count  151577.000000                     151577  151577.000000
# mean      -86.783749  0 days 00:12:10.027059207      12.163717
# std         0.695397  0 days 00:08:33.764416575       8.562600
# min      -122.428964            0 days 00:00:05       0.083333
# ...

# %%
july_trips = july_trips.loc[july_trips['duration_min'] < 41.42]
july_trips = july_trips.loc[july_trips['duration_min'] > 0]
july_trips = july_trips.loc[july_trips['tripDistance'] < 52800]
july_trips = july_trips.loc[july_trips['tripDistance'] > 0]
july_trips.describe()
# Out:
#        tripDistance  startLatitude  startLongitude   endLatitude  \
# count  97938.000000   97938.000000    97938.000000  97938.000000
# mean    5232.844871      36.156664      -86.785070     36.156984
# std     4695.719535       0.011068        0.013854      0.075058
# min        2.428921      36.037117      -86.890850     27.948352
# 25%     1929.130980      36.150905      -86.792900     36.151000
# 50%     3937.008000      36.157155      -86.782240     36.157670
# 75%     7233.600000      36.162900      -86.776689     36.162750
# max    52621.408883      36.299569      -86.610609     51.045409
#
#        endLongitude             duration_clean  duration_min
# count  97938.000000                      97938  97938.000000
# mean     -86.786046  0 days 00:13:07.415986475     13.119848
# std        0.353595  0 days 00:09:28.145343350      9.469015
# min     -122.673729            0 days 00:00:05      0.083333
# 25%      -86.792080     0 days 00:05:39.210833      5.650000
# ...

# %%
plt.hist(june_trips.duration_min, bins = 50, color = '#1F375D')
plt.title('Duration Distribution After Cleaning')
plt.xlabel('Duration in Minutes')
plt.ylabel('Count of Trips')
plt.show()

# %%
plt.hist(june_trips.tripDistance, bins = 50, color = '#1F375D')
plt.title('Trip Distance Distribution After Cleaning')
plt.xlabel('Trip Distance in Feet')
plt.ylabel('Count of Trips')
plt.show()

# %%
plt.scatter('duration_min', 'tripDistance', data = june_trips, color = '#1F375D', s = .5)
plt.xlabel('Duration in Minutes')
plt.ylabel('Distance in Feet')
plt.title('Duration v. Distance After Cleaning')
plt.show()

# %% [markdown]
# ## so close. still having some problems.

# %%
longtrips = june_trips.loc[(june_trips.duration_min > 1000)]
longtrips
# Out:
#                       pubTimeStamp companyName tripRecordNum  \
# 17782   2019-06-02 17:03:34.193000        SPIN       SPI1296
# 25093   2019-06-03 14:01:33.487000        Lyft        LFT924
# 29197   2019-06-04 00:34:41.057000        SPIN       SPI1042
# 32853   2019-06-04 19:20:20.920000        SPIN        SPI438
# 50371   2019-06-07 18:07:52.250000        SPIN        SPI412
# ...                            ...         ...           ...
# 205622         2019-07-01 19:58:07        JUMP         JMP56
# 205623         2019-07-01 19:58:07        JUMP         JMP53
# 205624         2019-07-01 19:58:07        JUMP         JMP52
# 205625         2019-07-01 19:58:07        JUMP         JMP54
# 205626         2019-07-01 19:58:07        JUMP         JMP50
#
#                                              sumdID  tripDuration  \
# 17782                                Powered4121208   1080.000000
# 25093                                 Powered811839   1036.416533
# ...

# %% [markdown]
# ## i think we'd have to plot these trips to see if they look legit. they are showing not very long, but is possible people just hung onto scoots for multiple days and ended up returning them right around where they got them.
#
# gonna create a sub to exclude outliers (using the technical def of 3rd - 1st quartile * 1.5)<br>
# 18.02 - 5.01 = 13.01<br>
# 13.01 1.5 = 19.515<br>
# 19.515 + 18.02 = 37.535

# %%
june_adj = june_trips.loc[(june_trips.duration_min < 38)]
june_adj.describe()

# %%
plt.scatter('duration_min', 'tripDistance', data = june_adj, color = '#2a9d8f')
plt.xlabel('Duration in Minutes')
plt.ylabel('Distance in Feet')
plt.title('Duration v. Distance')
plt.show()

# %%
plt.hist(june_adj.duration_min, bins = 100)
plt.xticks(rotation=50)
plt.title('Duration Distribution')
plt.xlabel('Minutes')
plt.ylabel('Count of Trips')
plt.show()

# %%
negs_adj = june_trips.loc[(june_trips.duration_min < 0)]
negs = negs_adj[['tripDistance', 'startDate', 'startTime', 'startDateTime_clean', 'endDate', 'endTime', 'endDateTime_clean', 'duration_min', 'tripRoute']]
negs

# %%
june_trips.info()

# %%
plt.hist(june_trips.startTime_clean, bins = 10)
plt.xticks(rotation=50)
plt.title('Start Time Distribution')
plt.show()
